# %%
import pandas as pd

df = pd.read_csv("../../data/developer_ai_learning_raw.csv")
df.shape
df.head
df.sample()
# Out:
#        ResponseId              Age  YearsCode DevType  \
# 22479       22480  35-44 years old        NaN     NaN
#
#                                          LearnCodeChoose LearnCode  \
# 22479  No, I am not new to coding and did not learn n...       NaN
#
#                                              LearnCodeAI AILearnHow AISelect  \
# 22479  Yes, I learned how to use AI-enabled tools req...        NaN      NaN
#
#       AIAcc AISent
# 22479   NaN    NaN

# %%
df.columns
df.dtypes
# Out:
# ResponseId           int64
# Age                    str
# YearsCode          float64
# DevType                str
# LearnCodeChoose        str
# LearnCode              str
# LearnCodeAI            str
# AILearnHow             str
# AISelect               str
# AIAcc                  str
# AISent                 str
# dtype: object

# %%
df.info()

# %%
df.isna().sum()

# %%
df.duplicated().sum()

# %%
df.nunique()

# %%
df.unique()

# %%
df.value_counts()
